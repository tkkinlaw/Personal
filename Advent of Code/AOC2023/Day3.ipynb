# %%
#txt = open(r"/Users/timothy/Documents/GitHub/Personal/Advent of Code/AOC2023/Data/day3Part1.txt")
#input = txt.read()
input = """467..114..
...*......
..35..633.
......#...
617*......
.....+.58.
..592.....
......755.
...$.*....
.664.598.."""
print(input)
# Out:
# 467..114..
# ...*......
# ..35..633.
# ......#...
# 617*......
# .....+.58.
# ..592.....
# ......755.
# ...$.*....
# .664.598..

# %%
inputChars = set(input.replace('\n','').replace('.',''))
print(inputChars)
numChars = set(str(i) for i in range(1, 10, 1))
print(numChars)

symbols = list(inputChars.difference(numChars))
symbols
# Out:
# {'9', '2', '+', '6', '4', '7', '3', '5', '8', '1', '*', '#', '$'}
# {'9', '2', '4', '6', '7', '5', '3', '8', '1'}
# ['+', '#', '$', '*']

# %%
import numpy as np
length = len(input.split('\n'))
width = len(input.split('\n')[0])
print(f"The width is {width} and the length is {length}")
# Out:
# The width is 10 and the length is 10

# %%
for row in input.split('\n'):
    print(row)
# Out:
# 467..114..
# ...*......
# ..35..633.
# ......#...
# 617*......
# .....+.58.
# ..592.....
# ......755.
# ...$.*....
# .664.598..

# %%
def searchDir(argRow, argNum):
    if argNum == 1:
        argRow[# Look left

# %%
i=0
for char in "...*......":
    if char == "*":
        print(i)
    i += 1
# Out:
# 3

# %%
t = 0
b = 0
l = 0
r = 0
tl = 0
tr = 0
bl = 0
br = 0
for row in input.split('\n'):
    topRow =row
# Out:
# 467..114..
# 467..114..
# 467..114..
# 467..114..
# 467..114..
# 467..114..
# 467..114..
# 467..114..
# 467..114..
# ...*......
# ...*......
# ...*......
# ...*......
# ...*......
# ...*......
# ...*......
# ...*......
# ...*......
# ..35..633.
# ..35..633.
# ..35..633.
# ..35..633.
# ..35..633.
# ..35..633.
# ..35..633.
# ..35..633.
# ..35..633.
# ......#...
# ......#...
# ......#...
# ......#...
# ......#...
# ......#...
# ......#...
# ......#...
# ......#...
# 617*......
# 617*......
# 617*......
# 617*......
# 617*......
# 617*......
# 617*......
# 617*......
# 617*......
# .....+.58.
# .....+.58.
# .....+.58.
# .....+.58.
# .....+.58.
# .....+.58.
# .....+.58.
# .....+.58.
# .....+.58.
# ..592.....
# ..592.....
# ..592.....
# ..592.....
# ..592.....
# ..592.....
# ..592.....
# ..592.....
# ..592.....
# ......755.
# ......755.
# ......755.
# ......755.
# ......755.
# ......755.
# ......755.
# ......755.
# ......755.
# ...$.*....
# ...$.*....
# ...$.*....
# ...$.*....
# ...
