# %%
import pandas as pd

# %%
input = r"""Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green
Game 2: 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue
Game 3: 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red
Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red
Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green"""

# %%
gameDict = []
for line in input.split("\n"):
    newLine = []
    for item in line.split(" "):
        if item != "," or item != ",":
            item=item.replace(",","")
            item=item.replace(";","")
            newLine.append(item.replace(":",""))
    print(newLine)
    # Add each game to the list, as a dictionary of rgb values
    i=0
    for value in newLine:
        if i%2==True:
            print("Yes")
        else:
            print("No")
# Out:
# ['Game', '1', '3', 'blue', '4', 'red', '1', 'red', '2', 'green', '6', 'blue', '2', 'green']
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# ['Game', '2', '1', 'blue', '2', 'green', '3', 'green', '4', 'blue', '1', 'red', '1', 'green', '1', 'blue']
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# ['Game', '3', '8', 'green', '6', 'blue', '20', 'red', '5', 'blue', '4', 'red', '13', 'green', '5', 'green', '1', 'red']
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# ['Game', '4', '1', 'green', '3', 'red', '6', 'blue', '3', 'green', '6', 'red', '3', 'green', '15', 'blue', '14', 'red']
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# ['Game', '5', '6', 'red', '1', 'blue', '3', 'green', '2', 'blue', '1', 'red', '2', 'green']
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
