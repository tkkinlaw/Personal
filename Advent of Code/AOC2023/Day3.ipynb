# %%
#txt = open(r"/Users/timothy/Documents/GitHub/Personal/Advent of Code/AOC2023/Data/day3Part1.txt")
#input = txt.read()
input = """467..114..
...*......
..35..633.
......#...
617*......
.....+.58.
..592.....
......755.
...$.*....
.664.598.."""
print(input)
# Out:
# 467..114..
# ...*......
# ..35..633.
# ......#...
# 617*......
# .....+.58.
# ..592.....
# ......755.
# ...$.*....
# .664.598..

# %%
inputChars = set(input.replace('\n','').replace('.',''))
print(inputChars)
numChars = set(str(i) for i in range(1, 10, 1))
print(numChars)

symbols = list(inputChars.difference(numChars))
symbols
# Out:
# {'*', '4', '$', '9', '3', '2', '7', '#', '6', '1', '8', '5', '+'}
# {'4', '3', '2', '7', '9', '6', '1', '8', '5'}
# ['*', '$', '#', '+']

# %%
import numpy as np
length = len(input.split('\n'))
width = len(input.split('\n')[0])
print(f"The width is {width} and the length is {length}")
# Out:
# The width is 10 and the length is 10

# %%
for row, col, in len(range(0,length+1)), len(range(0,width,1)):
    print(f"row: {row}, col: {col}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 for row, col, in len(range(0,length+1)), len(range(0,width,1)):
#       2     print(f"row: {row}, col: {col}")
#
# TypeError: cannot unpack non-iterable int object

# %%
for (x, y) in ([1,2,4], [1,2,5]):
    print(x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 for (x, y) in ([1,2,4], [1,2,5]):
#       2     print(x, y)
#
# ValueError: too many values to unpack (expected 2)
